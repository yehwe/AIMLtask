# %%
import numpy as np
num = [10, 25, 7, 42, 18,30, 100, 88]
arr=np.array(num)
mean_value = np.mean(arr)
max_value = np.max(arr)
sum_value = np.sum(arr)
print("list:", num)
print("NumPy array:", arr)
print("Mean:", mean_value)
print("Max value:", max_value)
print("Sum:", sum_value)
# Out:
# list: [10, 25, 7, 42, 18, 30, 100, 88]
# NumPy array: [ 10  25   7  42  18  30 100  88]
# Mean: 40.0
# Max value: 100
# Sum: 320
